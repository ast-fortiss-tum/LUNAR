# %% [markdown]
# # Customization of LUNAR
#
# TODO explain what to do to apply:
# - to other SUT
# - Case study.
# - How to define features file,
# - where/how to define fitness/critical function,
# - simulation function
# - chatbot
# - configure args
